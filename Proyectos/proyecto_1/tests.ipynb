% %%
%plot gnuplot

% %%
addpath ("files")
setenv('GNUTERM','qt')
format long

% %%
plot_surface(@rosenbrock)
[W,x,iter] = metodoblhibrido(@rosenbrock,[2,2]','newton',false);
x
rosenbrock(x)
valores_propios = !any(eig(hessiana(@rosenbrock,x)) < 0)
gradient = norm(gradiente(@rosenbrock,x))
%1,1 y vale cero
% Out:
% x =
%
%    9.999762814705050e-01
%    9.999525492964584e-01
%
% ans =    5.625888256322287e-10
% valores_propios = 1
% gradient =    7.347675603148457e-06

% %%
plot_surface(@rastrigin)
[W,x,iter] = metodoblhibrido(@rastrigin,[.4,.3]','max',false);
x
rastrigin(x)
valores_propios = !any(eig(hessiana(@rastrigin,x)) < 0)
gradient = norm(gradiente(@rastrigin,x))
%0,0 vale cero mín global
% Out:
% x =
%
%   -1.989288729940347
%   -1.989728706547448
%
% ans =  7.959746015645386
% valores_propios = 1
% gradient =    2.573698110117660e-01

% %%
%plot_surface(@griewank)
[W,x,iter] = metodoblhibrido(@griewank,[2,0]','newton',false);
x
griewank(x)
valores_propios = !any(eig(hessiana(@griewank,x)) < 0)
gradient = norm(gradiente(@griewank,x))
%0,0 vale cero
% Out:
% x =
%
%    3.069952103133800e+00
%    6.429289136918794e-04
%
% ans =  1.999790961635588
% valores_propios = 0
% gradient =    7.311490535663348e-02

% %%
[W,x,iter] = metodoblhibrido(@ackley,[0,1.5]','max',false);
x
ackley(x)
valores_propios = !any(eig(hessiana(@ackley,x)) < 0)
gradient = norm(gradiente(@ackley,x))
% Out:
% x =
%
%    5.031226179516731e-03
%    1.364214251507901e-02
%
% ans =    4.674708522691562e-02
% valores_propios = 1
% gradient =  3.600331364070826

% %%
[W,x,iter] = metodoblhibrido(@branin,[-4,13]','newton',false);
x
branin(x)
valores_propios = !any(eig(hessiana(@branin,x)) < 0)
gradient = norm(gradiente(@branin,x))
% Out:
% x =
%
%   -3.141590926392812e+00
%    1.227499294973074e+01
%
% ans =    3.978873577524666e-01
% valores_propios = 1
% gradient =    6.789332511980559e-06

% %%
[W,x,iter] = metodoblhibrido(@easom,[4.5,4.5]','max',false);
x
easom(x)
valores_propios = !any(eig(hessiana(@easom,x)) < 0)
gradient = norm(gradiente(@easom,x))
% Out:
% x =
%
%    3.141591857376155
%    3.141591857376155
%
% ans =   -9.999999999980982e-01
% valores_propios = 1
% gradient =    3.165306396706491e-06

% %%
plot_surface(@shubert,[-4,4],[-4,4],80)
[W,x,iter] = metodoblhibrido(@shubert,[3,1]','max',false);
x
shubert(x)
valores_propios = !any(eig(hessiana(@shubert,x)) < 0)
gradient = norm(gradiente(@shubert,x))
% Out:
% x =
%
%    4.006992934773452e+02
%    3.689879069282007e+01
%
% ans = -186.7301719288233
% valores_propios = 1
% gradient =  2.621754333631543
